# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%time
# %%capture
# !pip install transformers
# Out:
# CPU times: user 31.5 ms, sys: 8.98 ms, total: 40.5 ms
# Wall time: 3.23 s

# %%
import os
import io
import requests
import numpy as np
import pandas as pd
import re
import zipfile
import random
import time
import csv
import datetime
from itertools import compress
from collections import Counter, defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

from transformers import AutoTokenizer, AutoConfig, AutoModelForPreTraining, \
                         AdamW, get_linear_schedule_with_warmup, \
                         TrainingArguments, BeamScorer, Trainer

import torch
from torch.utils.data import Dataset, random_split, DataLoader, \
                             RandomSampler, SequentialSampler

from IPython.display import clear_output

print(f"PyTorch version: {torch.__version__}")
# Out:
# PyTorch version: 1.10.0+cu111

# %%
if torch.cuda.is_available():
  DEVICE = 'cuda'
else:
  DEVICE = 'cpu'

# %%
MODEL           = 'models/' #{gpt2, gpt2-medium, gpt2-large, gpt2-xl}
SPECIAL_TOKENS  = { "bos_token": "<|BOS|>",
                    "eos_token": "<|EOS|>",
                    "unk_token": "<|UNK|>",                    
                    "pad_token": "<|PAD|>",
                    "sep_token": "<|SEP|>"}
MAXLEN          = 768

# %%
def get_tokenier(special_tokens=None):
    tokenizer = AutoTokenizer.from_pretrained('gpt2') #GPT2Tokenizer

    if special_tokens:
        tokenizer.add_special_tokens(special_tokens)
        print("Special tokens added")
    return tokenizer

def get_model(tokenizer, special_tokens=None, load_model_path=None):

    #GPT2LMHeadModel
    if special_tokens:
        config = AutoConfig.from_pretrained(MODEL, 
                                            bos_token_id=tokenizer.bos_token_id,
                                            eos_token_id=tokenizer.eos_token_id,
                                            sep_token_id=tokenizer.sep_token_id,
                                            pad_token_id=tokenizer.pad_token_id,
                                            output_hidden_states=False)
    else: 
        config = AutoConfig.from_pretrained(MODEL,                                     
                                            pad_token_id=tokenizer.eos_token_id,
                                            output_hidden_states=False)    

    #----------------------------------------------------------------#
    model = AutoModelForPreTraining.from_pretrained(MODEL, config=config)

    if special_tokens:
        #Special tokens added, model needs to be resized accordingly
        model.resize_token_embeddings(len(tokenizer))

    if load_model_path:
        model.load_state_dict(torch.load(load_model_path,map_location=torch.device(DEVICE)))

    model.to(DEVICE)
    return model

# %%
tokenizer = get_tokenier(special_tokens=SPECIAL_TOKENS)
model = get_model(tokenizer, special_tokens=SPECIAL_TOKENS,load_model_path=os.path.join(MODEL,'pytorch_model.bin'))
# Out:
# Special tokens added

# %%
title = "Australia beats India by 7 wickets in Nagpur test"
keywords = ['Nagpur', 'Cricket', 'test', 'Kohli', 'win']
kw = ','.join(keywords)

prompt = SPECIAL_TOKENS['bos_token'] + title + \
         SPECIAL_TOKENS['sep_token'] + kw + SPECIAL_TOKENS['sep_token']
         
generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)
generated = generated.to(DEVICE)

model.eval();

# %%
# Top-p (nucleus) text generation (10 samples):
sample_outputs = model.generate(generated, 
                                do_sample=True,   
                                min_length=100, 
                                max_length=MAXLEN,
                                top_k=30,                                 
                                top_p=0.7,        
                                temperature=0.9,
                                repetition_penalty=4.0,
                                early_stopping=True,
                                num_return_sequences=3
                                )

for i, sample_output in enumerate(sample_outputs):
    text = tokenizer.decode(sample_output, skip_special_tokens=True)
    a = len(title) + len(','.join(keywords))    
    print("{}: {}\n\n".format(i+1,  text[a:]))
# Out:
# 1: New Delhi: Australia beat South Africa and Bangladesh on Sunday to claim a record seven consecutive victories against the Indian Premier League (IPL) champions. The result came after five straight losses with Pakistan winning four of them – defeating Sri Lanka 3-0 at Kohima Stadium last month while scoring two runs from Tinku Thaouyun’s double off Anuradha Patel over three balls — including one run during an innings that ended 4 overs before it was completed as Karnataka crossed its 100th win under new captain Sushil Chandra Bose ahead for his maiden Test series debut since 2014 when he joined West Indies earlier this year amid speculation about him being brought back into contention if required due transfer fee issues were not addressed soon enough following suspension or criminal charges levelled out upon allegations made regarding Naveen Kabrawala/Rajesh Bhansali vs Kailash Vijayawada between 2013 & 2015.  In fact all six Tests won either via home ground matches versus IPLS opponents without conceding any loss despite facing stiff competition but their first ever victory had been achieved through bowlers who took advantage early fielding errors caused largely because they batted poorly even though no doubt most batsmen are aware how bad these conditions can be compared too so far … And yet there is something remarkable going beyond mere batting… It seems like cricket has become ‘auction theatre mode again". For those wondering what exactly does constitute auction stage? Well here's why we need your help
# We will keep you updated! If u wish please email us directly @napoli_batting@gmail https://tweeti1im5xgkvzr4d7jmqhf3b2cql9 pic | Twitter (@ANIIndia), Facebook(PIB): #AuctionStageForTheNationalistBJP#TeamOfFameIsComingToYouBySuspendedOffenceRules Against Cricket players.#DismantleDelhiMockdownOnTicketAgainstIndianWifeAndHeritageIWantYourMoneyBackWithNoImmediateImpressionIncomeAfterTaxesGovtUndertakingPaymentOverhaulalFundedAtHomeAsPTUExchangePolicyWillWorkAgain To Pay Off Your Debtors Who Have Already Taken Money Out Of You Now…. What happens next? No action needed…… We want more money! Our team wants everything!! Please consider donating our funds ASAP!! सक्ा� 🇮💥👏😂 😁 ❯️❗ ⓜhttps%253EdupeCorona⁦ 👀 Get Started Today : Auctions start today 1st March 2019 2nd May 2020 Three months later One week Later 5 August 2021 6 September 2022 9 October 2023 10 November 23rd 2024 11 December 25 th April 2025 12 January 26 st June 27 31 July 28 i am sorry.. I don't know where my wife works now.. she just lives alone?? Is her family alright??? This place needs someone else then someplace near me?? So many people should come visit nipin goons!!! Where did Kapoor get married???? He never wanted anyone…..but everyone knows such things!!!! How do Indians compete??? That would have helped alot bjp japanese game couldnt survive outside country,why doesn`e nere play anymore abroad Why isn'it happening right across Asia????? Can China really afford playing india games only than USA etc.? Its impossible cause Indians must learn English better Then Pakis also Play At Home But Mainstream Media Ignored Their Exceptions When They Are Not Punished After All By Cops Even Those With
#
#
# 2: New Delhi: The Indian cricket team beat Australia on Saturday with a massive seven-wicket win over Kohlakhand. Test captain Sachin Tendulkar and former West Indies opener Jayashwant Sinha made up for their losses to Pakistan at the semi final of ICC T20 series last week when they went ahead 516 against an average score between them (341) while Ishant Kaur scored 2265 runs during that match which saw South Africa bag three straight wins from nine matches till Sunday evening’s draw after losing out due 1st through four overs via five balls under pressure despite not conceding any first term ball since June 28 this year – all six times it was contested without batting batsman Suresh Raina or bowlers Virat Bhushan as well Asim Rizvi were among those who managed 100 per cent century pace before being replaced late night today morning “The results are pleasing indeed but what is worrying now…is how much has been lost compared To our own numbers? It will be difficult if we do manage 200 cr/hr game next time though so I am confident there won't even have one more loss like yesterday where many others did! There had already come into play two new players too; Rahul Dravid got tested again recently whereas he played almost half his innings tonight only because you cannot get good spinners here either — both Joshi Chanderji & Dharmendra Pradhan jibe about him playing very little offspinting role tomorrow …I feel bad thinking otherwise….we can definitely see some improvement soon" said Ranjana Thackeray whose side secured 3rd consecutive victory thanks largely upon fielding Mathew Bisht scoring 659 runts including 473 soloies alongwith 11 doubles.
#
#
# 3: New Delhi: The Indian team beat Australia 5-6 on Saturday to clinch a berth at the ICC’s grand final with five more matches remaining. While all three teams have qualified for this year's Commonwealth Games qualifying group stage (CCPG), which begins Sunday and ends Tuesday evening — two weeks before their home nations play Bangladesh against Sri Lanka again – it will be four games of seven overs that is decided during Monday morning Tests after six days from today onwards as both sides are set up based off last week “playing well together but not very closely due diligence towards preparation ahead so far under pressure or fatigue resulting otherwise while keeping us alert throughout every innings through rigorous training sessions/tests including physical & mental stress tests etc., said AICB chief Virat Kohlmani earlier here via video conferencing Friday night following an interview conducted over phone calls between his office manager Amitabh Bachchanand others besides officials present there since Thursday afternoon amid Covid restrictions announced across various states around country where COVID19 cases were reported early Wednesday midnight till 2 am IST tomorrow, he added without divulging further details about when these events would take place. In its statement released late into November 2021 announcing results declared out within 24 hoursof date alongwith several other important parameters such attendance numbers among women students who attended competitive cricket tournaments like World Twenty20 2020 International Championship 2019; participation rate amongst youth aged 15 years+, 18+ per cent below prequalifying age bracket being recorded only twice each month thereafter until 31 March 2022–21 February 2023 ; inclusion criteria also made mandatory prior entry examination(IPE) certificate required upon admission beyond eligibility period beginning 30 April next preceding declaration process initiated 21 May 23rd unless notified 1 June 28th if found guilty 22nd 27 December 29 16 September 10 July 6 August 8 October 11 January 12February 13March 14April 17January 19July 26December 25September 3October 4November 9Tuesday day schedule has been amended accordinglyfor those countries listed above  According sources quoted hereinabove noted how many batsmen had tested positive thusly : All except Kapil Sibal was given appropriate doses…he should now go straight back indoors….if any doubts arise regarding whether one sample could give accurate result then we can use ICMR protocol instead………..we don't want our own doctors taking care …..it makes no sense why they cannot conduct randomised clinical trials because what matters most right away lies outside them mind…………but still you guys know WHO guidelines!! Please kindly share your opinion! I agree!!!

# %%
text = tokenizer.decode(sample_outputs[0], skip_special_tokens=True)
text
# Out:
# 'Australia beats India by 7 wickets in Nagpur testNagpur,Cricket,test,Kohli,winNew Delhi: Australia beat South Africa and Bangladesh on Sunday to claim a record seven consecutive victories against the Indian Premier League (IPL) champions. The result came after five straight losses with Pakistan winning four of them – defeating Sri Lanka 3-0 at Kohima Stadium last month while scoring two runs from Tinku Thaouyun’s double off Anuradha Patel over three balls — including one run during an innings that ended 4 overs before it was completed as Karnataka crossed its 100th win under new captain Sushil Chandra Bose ahead for his maiden Test series debut since 2014 when he joined West Indies earlier this year amid speculation about him being brought back into contention if required due transfer fee issues were not addressed soon enough following suspension or criminal charges levelled out upon allegations made regarding Naveen Kabrawala/Rajesh Bhansali vs Kailash Vijayawada between 2013 & 2015.  In fact all six Tests won either via home ground matches versus IPLS opponents without conceding any loss despite facing stiff competition but their first ever victory had been achieved through bowlers who took advantage early fielding errors caused largely because they batted poorly even though no doubt most batsmen are aware how bad these conditions can be compared too so far … And yet there is something remarkable going beyond mere batting… It seems like cricket has become ‘auction theatre mode again". For those wondering what exactly does constitute auction stage? Well here\'s why we need your help\nWe will keep you updated! If u wish please email us directly @napoli_batting@gmail https://tweeti1im5xgkvzr4d7jmqhf3b2cql9 pic | Twitter (@ANIIndia), Facebook(PIB): #AuctionStageForTheNationalistBJP#TeamOfFameIsComingToYouBySuspendedOffenceRules Against Cricket players.#DismantleDelhiMockdownOnTicketAgainstIndianWifeAndHeritageIWantYourMoneyBackWithNoImmediateImpressionIncomeAfterTaxesGovtUndertakingPaymentOverhaulalFundedAtHomeAsPTUExchangePolicyWillWorkAgain To Pay Off Your Debtors Who Have Already Taken Money Out Of You Now…. What happens next? No action needed…… We want more money! Our team wants everything!! Please consider donating our funds ASAP!! सक्ा� 🇮💥👏😂 😁 ❯️❗ ⓜhttps%253EdupeCorona\u2066 👀 Get Started Today : Auctions start today 1st March 2019 2nd May 2020 Three months later One week Later 5 August 2021 6 September 2022 9 October 2023 10 November 23rd 2024 11 December 25 th April 2025 12 January 26 st June 27 31 July 28 i am sorry.. I don\'t know where my wife works now.. she just lives alone?? Is her family alright??? This place needs someone else then someplace near me?? So many people should come visit nipin goons!!! Where did Kapoor get married???? He never wanted anyone…..but everyone knows such things!!!! How do Indians compete??? That would have helped alot bjp japanese game couldnt survive outside country,why doesn`e nere play anymore abroad Why isn\'it happening right across Asia????? Can China really afford playing india games only than USA etc.? Its impossible cause Indians must learn English better Then Pakis also Play At Home But Mainstream Media Ignored Their Exceptions When They Are Not Punished After All By Cops Even Those With'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%time
# %%capture
# !pip install transformers
# Out:
# CPU times: user 31.5 ms, sys: 8.98 ms, total: 40.5 ms
# Wall time: 3.23 s

# %%
import os
import io
import requests
import numpy as np
import pandas as pd
import re
import zipfile
import random
import time
import csv
import datetime
from itertools import compress
from collections import Counter, defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

from transformers import AutoTokenizer, AutoConfig, AutoModelForPreTraining, \
                         AdamW, get_linear_schedule_with_warmup, \
                         TrainingArguments, BeamScorer, Trainer

import torch
from torch.utils.data import Dataset, random_split, DataLoader, \
                             RandomSampler, SequentialSampler

from IPython.display import clear_output

print(f"PyTorch version: {torch.__version__}")
# Out:
# PyTorch version: 1.10.0+cu111

# %%
if torch.cuda.is_available():
  DEVICE = 'cuda'
else:
  DEVICE = 'cpu'

# %%
MODEL           = 'models/' #{gpt2, gpt2-medium, gpt2-large, gpt2-xl}
SPECIAL_TOKENS  = { "bos_token": "<|BOS|>",
                    "eos_token": "<|EOS|>",
                    "unk_token": "<|UNK|>",                    
                    "pad_token": "<|PAD|>",
                    "sep_token": "<|SEP|>"}
MAXLEN          = 768

# %%
def get_tokenier(special_tokens=None):
    tokenizer = AutoTokenizer.from_pretrained('gpt2') #GPT2Tokenizer

    if special_tokens:
        tokenizer.add_special_tokens(special_tokens)
        print("Special tokens added")
    return tokenizer

def get_model(tokenizer, special_tokens=None, load_model_path=None):

    #GPT2LMHeadModel
    if special_tokens:
        config = AutoConfig.from_pretrained(MODEL, 
                                            bos_token_id=tokenizer.bos_token_id,
                                            eos_token_id=tokenizer.eos_token_id,
                                            sep_token_id=tokenizer.sep_token_id,
                                            pad_token_id=tokenizer.pad_token_id,
                                            output_hidden_states=False)
    else: 
        config = AutoConfig.from_pretrained(MODEL,                                     
                                            pad_token_id=tokenizer.eos_token_id,
                                            output_hidden_states=False)    

    #----------------------------------------------------------------#
    model = AutoModelForPreTraining.from_pretrained(MODEL, config=config)

    if special_tokens:
        #Special tokens added, model needs to be resized accordingly
        model.resize_token_embeddings(len(tokenizer))

    if load_model_path:
        model.load_state_dict(torch.load(load_model_path,map_location=torch.device(DEVICE)))

    model.to(DEVICE)
    return model

# %%
tokenizer = get_tokenier(special_tokens=SPECIAL_TOKENS)
model = get_model(tokenizer, special_tokens=SPECIAL_TOKENS,load_model_path=os.path.join(MODEL,'pytorch_model.bin'))
# Out:
# Special tokens added

# %%
title = "Australia beats India by 7 wickets in Nagpur test"
keywords = ['Nagpur', 'Cricket', 'test', 'Kohli', 'win']
kw = ','.join(keywords)

prompt = SPECIAL_TOKENS['bos_token'] + title + \
         SPECIAL_TOKENS['sep_token'] + kw + SPECIAL_TOKENS['sep_token']
         
generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)
generated = generated.to(DEVICE)

model.eval();

# %%
# Top-p (nucleus) text generation (10 samples):
sample_outputs = model.generate(generated, 
                                do_sample=True,   
                                min_length=100, 
                                max_length=MAXLEN,
                                top_k=30,                                 
                                top_p=0.7,        
                                temperature=0.9,
                                repetition_penalty=4.0,
                                early_stopping=True,
                                num_return_sequences=3
                                )

for i, sample_output in enumerate(sample_outputs):
    text = tokenizer.decode(sample_output, skip_special_tokens=True)
    a = len(title) + len(','.join(keywords))    
    print("{}: {}\n\n".format(i+1,  text[a:]))
# Out:
# 1: New Delhi: Australia has beaten the Indian cricketing world with a record seven-wicket win over South Africa to reach its maiden Test series at Kohlbergen Stadium here. In an exclusive interview on ThePrint’s Karnataka Today programme Tuesday evening (4 February), Cricket Association president J P Nadda said that there is no question of winning it all but if one side can score three runs then he would like for another team and not just Pakistan which should be part from today onwards too as well so far… “We have got good results against our rivals both countries who are playing together very nicely now despite being under different circumstances — we want them into this game because they will definitely beat us tomorrow when two sides come out ahead again after losing their last match during Wankhedeppa celebrations earlier than usual due time limit set down within four hours period … So yes I think you may get some positive result tonight – what about Bangladesh? But maybe your opinion might change later depending upon how fast things turn up otherwise why don't start celebrating yourself next week or even every day before 8 pm [Wednesday] night instead?" added Dinkar Gupta while talking via phone regarding his comments following West Indies defeat Saturday afternoon between New Zealand & Sri Lanka.  While referring back towards previous World Twenty20 matches where only eight players were given equal opportunities without any difficulty, Prasad Maheshwari was quick enough through multiple interviews saying such defeats do nothing more important nor does having success make him better player comparedto other cricketers.. It also shows lacklustre attitude toward others among those involved….and yet everyone wants victory!
#
#
# 2: New Delhi: Australia beat South Africa and Bangladesh on Saturday to clinch the maiden Test series win at Kohl’s Cricket Ground here. The three-day tour of Asia began with a draw against Sri Lanka which saw five teams from across two nations score over 70 runs each during their respective innings (60), followed up when they scored seven while scoring six after four overs – including one run as an opener for Virat Gangulya who was dismissed midway through his first career game this week due suspension following alleged domestic violence allegations made before he returned home earlier than scheduled last month but had resumed cricket later that day via video conferencing amid growing international concern about Covid spread among players being exposed too early or not adequately vaccinated properly despite repeated warnings given recently “inaccurately tested positive under COVID19 protocols…The result is likely very significant considering how much we have lost since yesterday evening onwards — there has been no loss until today morning so far! It will be interesting if it goes beyond just our performance numbers tomorrow; also whether any team can take advantage because most other countries are more worried now regarding safety norms/precautionary measures suchas wearing masks etc … This means every single Indian player must keep himself fit throughout all Tests & matches like everyone else should do except those coming off short careers…. I would hope some country does follow suit soon enough…..  As you know my record shows me amply above average both physically speaking then mentally what matters……..My only qualification besides playing professionally next year shall come out winning 20 games where none defeats us." A few days ago Kollam Singh Pandey became eligible again citing lacklustre batting performances leading him back into contention owing largely towards injury woes caused even though several top cricketers were available within hours once Kapil Sibal took charge ahead Ofom Prakash Javadekar stepped down without attending another match yet announced retirement Sunday night saying otherwise He missed almost 30 per cent batsman participation thus leaving many wondering why someone could become ineligible immediately? Why did people think Rahul Gandhi cannot play alongside Wankhedeep Soni instead??
#
#
# 3: New Delhi: Australia beat the country’s cricketing capital Mumbai on Thursday to reach a record single-day win over its arch rival for three consecutive days. In an emphatic victory that saw both teams emerge as dominant performers and have played up their dominance at home with pace of play (20 runs) against each other – it was not enough but they are still one run ahead from reaching double digits this year despite losing five straight Tests during which time only two Indian cricketers managed more than 50 per cent innings before retirement last month amid Covid pandemic crisis triggered due course change. The first Test came just six months after West Indies took charge under former captain Virat Koht following his resignation midway through 2019 while Pakistan lost four successive matches without any formality even though he had been made AICTE president twice since 2012 when then coach Imran Khan retired earlier next season citing health reasons “to retire prematurely owing some ill effects resulting directly or indirectly upon him having failed several tests related thereto… His exit would certainly be detrimental if all those who followed us were found out about our recent loss today; hence we will try hard towards defeating them tomorrow night so far keeping faith till such times eventuality is brought into focus again….we may also keep praying well knowing there shall always remain hope among you along side me once I am safely away….. We can see no reason why your defeat cannot continue forever like these defeats did throughout history …the best thing now lies behind everyone's resolve & determination — Shri @SachinJhansi_ picnickedit (@ShivVirgil19571), January 16 2020  It has come down nicely indeed considering how much work goes back inside every box!#MumbaiWonIndia #GoalsDelhi https://twitter.#PIBot4BHxzF2w6TZg0fLqk3v5p7b8Ud9YjOQAaDmRnbPruXI@Imrankhani 🇮🌲👏😂https!⁩ My heart breaks……
# With 100% wins above expectations, World Cup winning batsman Dhoni looks unstoppable
